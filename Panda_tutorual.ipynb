# %%
import pandas as pd

# %%
pd.DataFrame({'Yes':[40,20],'No':[23,11]},index=['row 1','row 2'])
# Out:
#        Yes  No
# row 1   40  23
# row 2   20  11

# %%
wine_reviews=pd.read_csv("C:/Users/mithu/Music/79acab35be50eaf1c383948ed3fd1129-407a02139ae1e134992b90b4b2b8c329b3d73a6a/winemag-data-130k-v2.csv",index_col=0)

# %%
wine_reviews.shape
# Out:
# (65499, 13)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#            ...
# 65494       France
# 65495    Australia
# 65496           US
# 65497           US
# 65498        Spain
# Name: country, Length: 65499, dtype: object

# %%
wine_reviews['country'][0]
# Out:
# 'Italy'

# %%
wine_reviews.loc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
wine_reviews.iloc[:,0]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#            ...
# 65494       France
# 65495    Australia
# 65496           US
# 65497           US
# 65498        Spain
# Name: country, Length: 65499, dtype: object

# %%
wine_reviews.iloc[:3,0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[[0,12,1],[1,2]]
# Out:
#                                           description   designation
# 0   Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 12  Slightly reduced, this wine offers a chalky, t...           NaN
# 1   This is ripe and fruity, a wine that is smooth...      Avidagos

# %%
wine_reviews.iloc[-5:,1]
# Out:
# 65494    Made from young vines from the Vaulorent porti...
# 65495    This is a big, fat, almost sweet-tasting Caber...
# 65496    Much improved over the unripe 2005, Fritz's 20...
# 65497    This wine wears its 15.8% alcohol better than ...
# 65498    A unique take on Manzanilla Sherry, which is o...
# Name: description, dtype: object

# %%
wine_reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
wine_reviews.loc[:,['country','taster_name']]
# Out:
#          country         taster_name
# 0          Italy       Kerin O’Keefe
# 1       Portugal          Roger Voss
# 2             US        Paul Gregutt
# 3             US  Alexander Peartree
# 4             US        Paul Gregutt
# ...          ...                 ...
# 65494     France          Roger Voss
# 65495  Australia      Joe Czerwinski
# 65496         US                 NaN
# 65497         US                 NaN
# 65498      Spain   Michael Schachner
#
# [65499 rows x 2 columns]

# %%
wine_reviews.country=='Italy'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 65494    False
# 65495    False
# 65496    False
# 65497    False
# 65498    False
# Name: country, Length: 65499, dtype: bool

# %%
wine_reviews[wine_reviews.country=='Italy']
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 6       Italy  Here's a bright, informal red that opens with ...
# 13      Italy  This is dominated by oak and oak-driven aromas...
# 22      Italy  Delicate aromas recall white flower and citrus...
# 24      Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...       ...                                                ...
# 65466   Italy  Earthy truffle, porcini mushroom, herb and gam...
# 65474   Italy  Made of 70% Syrah, 15% Sangiovese and 15% Merl...
# 65476   Italy  Rose, violet, sour berry and tilled earth arom...
# 65477   Italy  Made of 65% Merlot, 25% Cabernet Sauvignon, 5%...
# 65478   Italy  Aromas suggesting French oak, coconut and spic...
#
#         designation  points  price           province  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6           Belsito      87   16.0  Sicily & Sardinia
# ...

# %%
wine_reviews.loc[(wine_reviews.country=='Italy') & (wine_reviews.points>=9)]
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 6       Italy  Here's a bright, informal red that opens with ...
# 13      Italy  This is dominated by oak and oak-driven aromas...
# 22      Italy  Delicate aromas recall white flower and citrus...
# 24      Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...       ...                                                ...
# 65466   Italy  Earthy truffle, porcini mushroom, herb and gam...
# 65474   Italy  Made of 70% Syrah, 15% Sangiovese and 15% Merl...
# 65476   Italy  Rose, violet, sour berry and tilled earth arom...
# 65477   Italy  Made of 65% Merlot, 25% Cabernet Sauvignon, 5%...
# 65478   Italy  Aromas suggesting French oak, coconut and spic...
#
#         designation  points  price           province  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6           Belsito      87   16.0  Sicily & Sardinia
# ...

# %%
wine_reviews.loc[wine_reviews.country.isin(['Italy','Franch'])]
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 6       Italy  Here's a bright, informal red that opens with ...
# 13      Italy  This is dominated by oak and oak-driven aromas...
# 22      Italy  Delicate aromas recall white flower and citrus...
# 24      Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...       ...                                                ...
# 65466   Italy  Earthy truffle, porcini mushroom, herb and gam...
# 65474   Italy  Made of 70% Syrah, 15% Sangiovese and 15% Merl...
# 65476   Italy  Rose, violet, sour berry and tilled earth arom...
# 65477   Italy  Made of 65% Merlot, 25% Cabernet Sauvignon, 5%...
# 65478   Italy  Aromas suggesting French oak, coconut and spic...
#
#         designation  points  price           province  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6           Belsito      87   16.0  Sicily & Sardinia
# ...

# %%
wine_reviews.loc[wine_reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 65494     France  Made from young vines from the Vaulorent porti...
# 65495  Australia  This is a big, fat, almost sweet-tasting Caber...
# 65496         US  Much improved over the unripe 2005, Fritz's 20...
# 65497         US  This wine wears its 15.8% alcohol better than ...
# 65498      Spain  A unique take on Manzanilla Sherry, which is o...
#
#                               designation  points  price         province  \
# 1                                Avidagos      87   15.0            Douro
# ...

# %%
wine_reviews['critic']='everyone'

# %%
wine_reviews['critic']
# Out:
# 0        everyone
# 1        everyone
# 2        everyone
# 3        everyone
# 4        everyone
#            ...
# 65494    everyone
# 65495    everyone
# 65496    everyone
# 65497    everyone
# 65498    everyone
# Name: critic, Length: 65499, dtype: object

# %%
wine_reviews['index_backwards']=range(len(wine_reviews),0,-1)
wine_reviews['index_backwards']
# Out:
# 0        65499
# 1        65498
# 2        65497
# 3        65496
# 4        65495
#          ...
# 65494        5
# 65495        4
# 65496        3
# 65497        2
# 65498        1
# Name: index_backwards, Length: 65499, dtype: int32

# %%
reviews=wine_reviews

# %%
reviews.points.describe()
# Out:
# count    65499.000000
# mean        88.434037
# std          3.030310
# min         80.000000
# 25%         86.000000
# 50%         88.000000
# 75%         91.000000
# max        100.000000
# Name: points, dtype: float64

# %%
reviews.taster_name.describe()
# Out:
# count          51856
# unique            19
# top       Roger Voss
# freq           13045
# Name: taster_name, dtype: object

# %%
reviews.taster_name.unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.describe()
# Out:
#              points         price  index_backwards
# count  65499.000000  60829.000000     65499.000000
# mean      88.434037     35.232932     32750.000000
# std        3.030310     39.477858     18908.076978
# min       80.000000      4.000000         1.000000
# 25%       86.000000     17.000000     16375.500000
# 50%       88.000000     25.000000     32750.000000
# 75%       91.000000     42.000000     49124.500000
# max      100.000000   2500.000000     65499.000000

# %%
reviews.taster_name.describe()
# Out:
# count          51856
# unique            19
# top       Roger Voss
# freq           13045
# Name: taster_name, dtype: object

# %%
reviews.points.median()
# Out:
# 88.0

# %%
reviews.points.value_counts()
# Out:
# 87     8872
# 88     8423
# 90     7697
# 86     6179
# 91     6016
# 89     5724
# 85     5082
# 92     4917
# 84     3490
# 93     3268
# 94     1905
# 83     1442
# 82      923
# 95      678
# 81      305
# 96      262
# 80      155
# 97       99
# 98       39
# 99       15
# 100       8
# Name: points, dtype: int64

# %%
review_points_mean=reviews.points.mean()
reviews.points.map(lambda p:p-review_points_mean)
# Out:
# 0       -1.434037
# 1       -1.434037
# 2       -1.434037
# 3       -1.434037
# 4       -1.434037
#            ...
# 65494    1.565963
# 65495    1.565963
# 65496    1.565963
# 65497    1.565963
# 65498    1.565963
# Name: points, Length: 65499, dtype: float64

# %%
reviews.points
# Out:
# 0        87
# 1        87
# 2        87
# 3        87
# 4        87
#          ..
# 65494    90
# 65495    90
# 65496    90
# 65497    90
# 65498    90
# Name: points, Length: 65499, dtype: int64

# %%
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 65494     France  Made from young vines from the Vaulorent porti...
# 65495  Australia  This is a big, fat, almost sweet-tasting Caber...
# 65496         US  Much improved over the unripe 2005, Fritz's 20...
# 65497         US  This wine wears its 15.8% alcohol better than ...
# 65498      Spain  A unique take on Manzanilla Sherry, which is o...
#
#                               designation    points  price           province  \
# ...

# %%
reviews.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
reviews.country+' - '+reviews.region_1
# Out:
# 0                    Italy - Etna
# 1                             NaN
# 2          US - Willamette Valley
# 3        US - Lake Michigan Shore
# 4          US - Willamette Valley
#                    ...
# 65494            France - Chablis
# 65495    Australia - McLaren Vale
# 65496       US - Dry Creek Valley
# 65497            US - Napa Valley
# 65498               Spain - Jerez
# Length: 65499, dtype: object

# %%
reviews.groupby(['points']).points.count()
# Out:
# points
# 80      155
# 81      305
# 82      923
# 83     1442
# 84     3490
# 85     5082
# 86     6179
# 87     8872
# 88     8423
# 89     5724
# 90     7697
# 91     6016
# 92     4917
# 93     3268
# 94     1905
# 95      678
# 96      262
# 97       99
# 98       39
# 99       15
# 100       8
# Name: points, dtype: int64

# %%
reviews.groupby(['country']).points.min()
# Out:
# country
# Argentina                 80
# Armenia                   87
# Australia                 80
# Austria                   82
# Bosnia and Herzegovina    85
# Brazil                    80
# Bulgaria                  82
# Canada                    82
# Chile                     80
# Croatia                   82
# Cyprus                    85
# Czech Republic            85
# England                   89
# France                    80
# Georgia                   83
# Germany                   81
# Greece                    82
# Hungary                   81
# India                     89
# Israel                    80
# Italy                     80
# Lebanon                   82
# Luxembourg                88
# Macedonia                 87
# Mexico                    82
# Moldova                   82
# Morocco                   85
# New Zealand               80
# Peru                      81
# Portugal                  80
# Romania                   82
# ...

# %%
reviews.groupby(['winery']).apply(lambda df:df.title.iloc[0])
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
# 1000 Stories           1000 Stories 2013 Bourbon Barrel Aged Zinfande...
# 1070 Green                  1070 Green 2011 Sauvignon Blanc (Rutherford)
#                                              ...
# Órale                       Órale 2011 Cabronita Red (Santa Ynez Valley)
# Öko                    Öko 2013 Made With Organically Grown Grapes Ma...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 13549, dtype: object

# %%
reviews.groupby(['country','province']).apply(lambda df:df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# Armenia   Armenia             Armenia
# Australia Australia Other   Australia
#           New South Wales   Australia
# ...                               ...
# Uruguay   Juanico             Uruguay
#           Montevideo          Uruguay
#           Progreso            Uruguay
#           San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If you love massive Argentine reds with purity...
#           Other             This single-vineyard Malbec blend from vineyar...
# Armenia   Armenia           Medium straw in the glass, this wine has a nos...
# Australia Australia Other   Writes the book on how to make a wine filled w...
# ...

# %%
reviews.groupby(['country']).price.agg([len,min,max])
# Out:
#                             len   min     max
# country
# Argentina                1907.0   4.0   230.0
# Armenia                     1.0  14.0    14.0
# Australia                1177.0   6.0   850.0
# Austria                  1635.0   7.0   150.0
# Bosnia and Herzegovina      1.0  13.0    13.0
# Brazil                     31.0  10.0    45.0
# Bulgaria                   68.0   8.0    55.0
# Canada                    108.0  12.0   120.0
# Chile                    2258.0   5.0   400.0
# Croatia                    44.0  13.0    65.0
# Cyprus                      6.0  11.0    21.0
# Czech Republic              6.0  15.0    45.0
# England                    36.0  25.0    80.0
# France                  11174.0   5.0  2500.0
# Georgia                    37.0   9.0    40.0
# Germany                  1051.0   5.0   775.0
# Greece                    242.0   8.0    79.0
# Hungary                    61.0  10.0   764.0
# India                       4.0  10.0    20.0
# ...

# %%
mi=reviews.groupby(['country', 'province']).points.agg([len])

# %%
mi
# Out:
#                              len
# country   province
# Argentina Mendoza Province  1635
#           Other              272
# Armenia   Armenia              1
# Australia Australia Other    131
#           New South Wales     34
# ...                          ...
# Uruguay   Juanico              8
#           Montevideo          10
#           Progreso             5
#           San Jose             3
#           Uruguay              7
#
# [385 rows x 1 columns]

# %%
mi.index
# Out:
# MultiIndex([('Argentina',  'Mendoza Province'),
#             ('Argentina',             'Other'),
#             (  'Armenia',           'Armenia'),
#             ('Australia',   'Australia Other'),
#             ('Australia',   'New South Wales'),
#             ('Australia',   'South Australia'),
#             ('Australia',          'Tasmania'),
#             ('Australia',          'Victoria'),
#             ('Australia', 'Western Australia'),
#             (  'Austria',           'Austria'),
#             ...
#             (       'US',        'Washington'),
#             (       'US', 'Washington-Oregon'),
#             (  'Ukraine',           'Ukraine'),
#             (  'Uruguay',         'Atlantida'),
#             (  'Uruguay',         'Canelones'),
#             (  'Uruguay',           'Juanico'),
#             (  'Uruguay',        'Montevideo'),
#             (  'Uruguay',          'Progreso'),
#             (  'Uruguay',          'San Jose'),
# ...

# %%
mi.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  1635
# 1    Argentina             Other   272
# 2      Armenia           Armenia     1
# 3    Australia   Australia Other   131
# 4    Australia   New South Wales    34
# ..         ...               ...   ...
# 380    Uruguay           Juanico     8
# 381    Uruguay        Montevideo    10
# 382    Uruguay          Progreso     5
# 383    Uruguay          San Jose     3
# 384    Uruguay           Uruguay     7
#
# [385 rows x 3 columns]

# %%
mi=mi.reset_index()
mi.sort_values(by='len',ascending=False)
# Out:
#           country     province    len
# 353            US   California  18122
# 375            US   Washington   4308
# 110        France     Bordeaux   3014
# 204         Italy      Tuscany   2985
# 369            US       Oregon   2691
# ..            ...          ...    ...
# 289      Slovenia    Dolenjska      1
# 291      Slovenia         Kras      1
# 293      Slovenia     Slovenia      1
# 329  South Africa  Vlootenburg      1
# 139        Greece       Beotia      1
#
# [385 rows x 3 columns]

# %%
mi.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  1635
# 1    Argentina             Other   272
# 2      Armenia           Armenia     1
# 3    Australia   Australia Other   131
# 4    Australia   New South Wales    34
# ..         ...               ...   ...
# 380    Uruguay           Juanico     8
# 381    Uruguay        Montevideo    10
# 382    Uruguay          Progreso     5
# 383    Uruguay          San Jose     3
# 384    Uruguay           Uruguay     7
#
# [385 rows x 3 columns]

# %%
mi.sort_values(by=['country','len'])
# Out:
#        country          province   len
# 1    Argentina             Other   272
# 0    Argentina  Mendoza Province  1635
# 2      Armenia           Armenia     1
# 6    Australia          Tasmania    23
# 4    Australia   New South Wales    34
# ..         ...               ...   ...
# 382    Uruguay          Progreso     5
# 384    Uruguay           Uruguay     7
# 380    Uruguay           Juanico     8
# 381    Uruguay        Montevideo    10
# 379    Uruguay         Canelones    24
#
# [385 rows x 3 columns]

# %%
reviews.price.dtype
# Out:
# dtype('float64')

# %%
reviews.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# critic                    object
# index_backwards            int32
# dtype: object

# %%
reviews.points.astype('float64')
# Out:
# 0        87.0
# 1        87.0
# 2        87.0
# 3        87.0
# 4        87.0
#          ...
# 65494    90.0
# 65495    90.0
# 65496    90.0
# 65497    90.0
# 65498    90.0
# Name: points, Length: 65499, dtype: float64

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#       country                                        description  \
# 913       NaN  Amber in color, this wine has aromas of peach ...
# 3131      NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243      NaN  Violet-red in color, this semisweet wine has a...
# 9509      NaN  This mouthwatering blend starts with a nose of...
# 9750      NaN  This orange-style wine has a cloudy yellow-gol...
# 11150     NaN  A blend of 85% Melnik, 10% Grenache Noir and 5...
# 11348     NaN  Light and fruity, this is a wine that has some...
# 14030     NaN  This Furmint, grown in marl soils, has aromas ...
# 16000     NaN  Jumpy, jammy aromas of foxy black fruits are s...
# 16749     NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 18075     NaN  Delicate white flowers and a spin of lemon pee...
# 26485     NaN  This wine has aromas of black berry, dried red...
# 26486     NaN  Aromas of green apple and white flowers prepar...
# ...

# %%
reviews.region_2.fillna('Unknown')
# Out:
# 0                  Unknown
# 1                  Unknown
# 2        Willamette Valley
# 3                  Unknown
# 4        Willamette Valley
#                ...
# 65494              Unknown
# 65495              Unknown
# 65496               Sonoma
# 65497                 Napa
# 65498              Unknown
# Name: region_2, Length: 65499, dtype: object

# %%
reviews.taster_twitter_handle.replace('@kerinokeefe','@kerino')
# Out:
# 0            @kerino
# 1         @vossroger
# 2        @paulgwine
# 3                NaN
# 4        @paulgwine
#             ...
# 65494     @vossroger
# 65495         @JoeCz
# 65496            NaN
# 65497            NaN
# 65498    @wineschach
# Name: taster_twitter_handle, Length: 65499, dtype: object

# %%
reviews.rename(columns={'points':'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 65494     France  Made from young vines from the Vaulorent porti...
# 65495  Australia  This is a big, fat, almost sweet-tasting Caber...
# 65496         US  Much improved over the unripe 2005, Fritz's 20...
# 65497         US  This wine wears its 15.8% alcohol better than ...
# 65498      Spain  A unique take on Manzanilla Sherry, which is o...
#
#                               designation  score  price           province  \
# ...

# %%
reviews.rename(index={0:'firstentry',1:'secondetry'})
# Out:
#               country                                        description  \
# firstentry      Italy  Aromas include tropical fruit, broom, brimston...
# secondetry   Portugal  This is ripe and fruity, a wine that is smooth...
# 2                  US  Tart and snappy, the flavors of lime flesh and...
# 3                  US  Pineapple rind, lemon pith and orange blossom ...
# 4                  US  Much like the regular bottling from 2012, this...
# ...               ...                                                ...
# 65494          France  Made from young vines from the Vaulorent porti...
# 65495       Australia  This is a big, fat, almost sweet-tasting Caber...
# 65496              US  Much improved over the unripe 2005, Fritz's 20...
# 65497              US  This wine wears its 15.8% alcohol better than ...
# 65498           Spain  A unique take on Manzanilla Sherry, which is o...
#
#                                    designation  points  price  \
# ...

# %%
reviews.rename_axis('wines',axis='rows').rename_axis('fields',axis='columns')
# Out:
# fields    country                                        description  \
# wines
# 0           Italy  Aromas include tropical fruit, broom, brimston...
# 1        Portugal  This is ripe and fruity, a wine that is smooth...
# 2              US  Tart and snappy, the flavors of lime flesh and...
# 3              US  Pineapple rind, lemon pith and orange blossom ...
# 4              US  Much like the regular bottling from 2012, this...
# ...           ...                                                ...
# 65494      France  Made from young vines from the Vaulorent porti...
# 65495   Australia  This is a big, fat, almost sweet-tasting Caber...
# 65496          US  Much improved over the unripe 2005, Fritz's 20...
# 65497          US  This wine wears its 15.8% alcohol better than ...
# 65498       Spain  A unique take on Manzanilla Sherry, which is o...
#
# fields                         designation  points  price           province  \
# wines
# ...
